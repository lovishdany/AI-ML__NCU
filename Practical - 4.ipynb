# %% [markdown]
# <a href="https://colab.research.google.com/github/lovishdany/AI-ML__NCU/blob/main/Practical%20-%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df=pd.read_csv("Data.csv")
df2=df.copy()
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
encoder=LabelEncoder()

# %%
df["Country-Label"]=encoder.fit_transform(df["Country"])
df
# Out:
#    Country   Age   Salary Purchased  Country-Label
# 0   France  44.0  72000.0        No              0
# 1    Spain  27.0  48000.0       Yes              2
# 2  Germany  30.0  54000.0        No              1
# 3    Spain  38.0  61000.0        No              2
# 4  Germany  40.0      NaN       Yes              1
# 5   France  35.0  58000.0       Yes              0
# 6    Spain   NaN  52000.0        No              2
# 7   France  48.0  79000.0       Yes              0
# 8  Germany  50.0  83000.0        No              1
# 9   France  37.0  67000.0       Yes              0

# %%
onehotencoder = pd.get_dummies(df, columns=["Purchased"])
onehotencoder
# Out:
#    Country   Age   Salary  Purchased_No  Purchased_Yes
# 0        0  44.0  72000.0             1              0
# 1        2  27.0  48000.0             0              1
# 2        1  30.0  54000.0             1              0
# 3        2  38.0  61000.0             1              0
# 4        1  40.0      NaN             0              1
# 5        0  35.0  58000.0             0              1
# 6        2   NaN  52000.0             1              0
# 7        0  48.0  79000.0             0              1
# 8        1  50.0  83000.0             1              0
# 9        0  37.0  67000.0             0              1

# %%
# one_hot_country= pd.get_dummies(df2,columns=["Country"])
# one_hot_country
# Out:
#     Age   Salary Purchased  Country_France  Country_Germany  Country_Spain
# 0  44.0  72000.0        No               1                0              0
# 1  27.0  48000.0       Yes               0                0              1
# 2  30.0  54000.0        No               0                1              0
# 3  38.0  61000.0        No               0                0              1
# 4  40.0      NaN       Yes               0                1              0
# 5  35.0  58000.0       Yes               1                0              0
# 6   NaN  52000.0        No               0                0              1
# 7  48.0  79000.0       Yes               1                0              0
# 8  50.0  83000.0        No               0                1              0
# 9  37.0  67000.0       Yes               1                0              0

# %%
one_hot_country=OneHotEncoder()
ohc=pd.DataFrame(one_hot_country.fit_transform(df[["Country-Label"]]).toarray())

# %%
new_df=df.join(ohc)
new_df
# Out:
#    Country   Age   Salary Purchased  Country-Label    0    1    2
# 0   France  44.0  72000.0        No              0  1.0  0.0  0.0
# 1    Spain  27.0  48000.0       Yes              2  0.0  0.0  1.0
# 2  Germany  30.0  54000.0        No              1  0.0  1.0  0.0
# 3    Spain  38.0  61000.0        No              2  0.0  0.0  1.0
# 4  Germany  40.0      NaN       Yes              1  0.0  1.0  0.0
# 5   France  35.0  58000.0       Yes              0  1.0  0.0  0.0
# 6    Spain   NaN  52000.0        No              2  0.0  0.0  1.0
# 7   France  48.0  79000.0       Yes              0  1.0  0.0  0.0
# 8  Germany  50.0  83000.0        No              1  0.0  1.0  0.0
# 9   France  37.0  67000.0       Yes              0  1.0  0.0  0.0

# %%
df2["Age-Label"]=encoder.fit_transform(df["Age"])
df2
# Out:
#    Country   Age   Salary Purchased  Age-Label
# 0   France  44.0  72000.0        No          6
# 1    Spain  27.0  48000.0       Yes          0
# 2  Germany  30.0  54000.0        No          1
# 3    Spain  38.0  61000.0        No          4
# 4  Germany  40.0      NaN       Yes          5
# 5   France  35.0  58000.0       Yes          2
# 6    Spain   NaN  52000.0        No          9
# 7   France  48.0  79000.0       Yes          7
# 8  Germany  50.0  83000.0        No          8
# 9   France  37.0  67000.0       Yes          3
